# %%
# import pandas as pd
import cudf as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/results.csv", index_col=0)

df
# Out:
#     Total Return  Annual Return  Volatility  Expected Return    Sharpe  \
# 0       0.909180       0.472547    0.035928         0.001993  0.876974
# 1       0.788319       0.409729    0.031110         0.001701  0.864309
# 2       0.533980       0.277536    0.027356         0.001267  0.732128
# 3       0.361282       0.187777    0.025678         0.000972  0.598796
# 4       0.236100       0.122713    0.024465         0.000741  0.479103
# ..           ...            ...         ...              ...       ...
# 95      0.312582       0.162465    0.019683         0.000760  0.610552
# 96      0.326561       0.169730    0.019674         0.000782  0.628400
# 97      0.332398       0.172764    0.019682         0.000791  0.635600
# 98      0.325650       0.169257    0.019659         0.000780  0.627498
# 99      0.335416       0.174332    0.019654         0.000795  0.639867
#
#     Correlation      Beta     Alpha  Size
# 0      0.270126  0.788323  0.001792     1
# ...

# %%
df = df.to_pandas()

sns.scatterplot(data=df,x='Size',y='Sharpe')
# Out:
# <Axes: xlabel='Size', ylabel='Sharpe'>

# %%
sns.scatterplot(data=df,x='Size',y='Annual Return')
# Out:
# <Axes: xlabel='Size', ylabel='Annual Return'>

# %%
sns.scatterplot(data=df,x='Size',y='Volatility')
# Out:
# <Axes: xlabel='Size', ylabel='Volatility'>

# %%
sns.scatterplot(data=df,x='Size',y='Beta')
# Out:
# <Axes: xlabel='Size', ylabel='Beta'>

# %%
sns.scatterplot(data=df,x='Size',y='Correlation')
# Out:
# <Axes: xlabel='Size', ylabel='Correlation'>

# %%
sns.scatterplot(data=df,x='Size',y='Alpha')
# Out:
# <Axes: xlabel='Size', ylabel='Alpha'>
