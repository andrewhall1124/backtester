# %%
# import pandas as pd
import cudf as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/results.csv", index_col=0)

df
# Out:
#     Total Return  Annual Return  Volatility  Expected Return    Sharpe  \
# 0       9.056449       1.301214    0.042908         0.002219  0.817740
# 1       3.991726       0.573524    0.034440         0.001506  0.691357
# 2       9.054424       1.300923    0.031449         0.001815  0.912499
# 3       7.240216       1.040261    0.032164         0.001718  0.844618
# 4       4.156030       0.597131    0.030009         0.001388  0.731062
# ..           ...            ...         ...              ...       ...
# 95      4.042989       0.580889    0.020402         0.001140  0.883332
# 96      4.144656       0.595497    0.020374         0.001151  0.893036
# 97      4.192689       0.602398    0.020363         0.001156  0.897503
# 98      4.240675       0.609292    0.020349         0.001161  0.902033
# 99      4.285975       0.615801    0.020349         0.001166  0.905881
#
#     Correlation      Beta  Size
# 0      0.291848  1.038555     1
# 1      0.370736  1.058927     2
# 2      0.405885  1.058640     3
# 3      0.418574  1.116557     4
# 4      0.467205  1.162770     5
# ..          ...       ...   ...
# 95     0.723586  1.224319    96
# 96     0.723638  1.222738    97
# 97     0.724338  1.223264    98
# 98     0.725381  1.224173    99
# 99     0.726332  1.225800   100
#
# [100 rows x 8 columns]

# %%
df.iloc[20:30,:]
# Out:
#     Total Return  Annual Return  Volatility  Expected Return    Sharpe  \
# 20      6.107508       0.877516    0.024326         0.001424  0.925720
# 21      6.661674       0.957137    0.024247         0.001465  0.955605
# 22      6.289714       0.903695    0.024086         0.001433  0.940659
# 23      6.892298       0.990273    0.024013         0.001477  0.972527
# 24      7.115213       1.022301    0.023925         0.001491  0.985349
# 25      7.471288       1.073461    0.023900         0.001515  1.002319
# 26      7.194050       1.033628    0.023762         0.001493  0.993297
# 27      7.161986       1.029021    0.023771         0.001491  0.991603
# 28      6.671323       0.958523    0.023678         0.001453  0.970292
# 29      6.129140       0.880624    0.023546         0.001408  0.945356
#
#     Correlation      Beta  Size
# 20     0.618855  1.248514    21
# 21     0.621049  1.248876    22
# 22     0.625829  1.250146    23
# 23     0.628536  1.251740    24
# 24     0.631510  1.253024    25
# 25     0.634872  1.258412    26
# 26     0.636963  1.255260    27
# 27     0.640534  1.262755    28
# 28     0.642906  1.262495    29
# 29     0.646945  1.263324    30

# %%
df = df.to_pandas()

sns.scatterplot(data=df,x='Size',y='Sharpe')
# Out:
# <Axes: xlabel='Size', ylabel='Sharpe'>

# %%
sns.scatterplot(data=df,x='Size',y='Annual Return')
# Out:
# <Axes: xlabel='Size', ylabel='Annual Return'>

# %%
sns.scatterplot(data=df,x='Size',y='Volatility')
# Out:
# <Axes: xlabel='Size', ylabel='Volatility'>

# %%
sns.scatterplot(data=df,x='Size',y='Beta')
# Out:
# <Axes: xlabel='Size', ylabel='Beta'>

# %%
sns.scatterplot(data=df,x='Size',y='Correlation')
# Out:
# <Axes: xlabel='Size', ylabel='Correlation'>
